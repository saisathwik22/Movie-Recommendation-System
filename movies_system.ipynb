# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('movies_metadata.csv')

# %% [markdown]
# # **Data Cleaning & Gathering**

# %%
df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
df.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
df.shape # rows & columns
# Out:
# (45466, 24)

# %%
df.isnull().sum() # number of null values in each column
# e.g.: there are 954 row entries whose 'overview' column in null
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
# 13 duplicated rows were present, so drop them
df = df.drop_duplicates().reset_index(drop = True)

# %%
df.duplicated().sum() # check again if correctly dropped
# Out:
# np.int64(0)

# %%
# relevant columns are included, irrelevant columns dropped
df = df[['title', 'overview', 'genres', 'tagline', 'vote_average', 'popularity']]

# %%
df
# Out:
#                              title  \
# 0                        Toy Story
# 1                          Jumanji
# 2                 Grumpier Old Men
# 3                Waiting to Exhale
# 4      Father of the Bride Part II
# ...                            ...
# 45448                       Subdue
# 45449          Century of Birthing
# 45450                     Betrayal
# 45451             Satan Triumphant
# 45452                     Queerama
#
#                                                 overview  \
# 0      Led by Woody, Andy's toys live happily in his ...
# 1      When siblings Judy and Peter discover an encha...
# 2      A family wedding reignites the ancient feud be...
# 3      Cheated on, mistreated and stepped on, the wom...
# 4      Just when George Banks has recovered from his ...
# ...                                                  ...
# 45448        Rising and falling between a man and woman.
# 45449  An artist struggles to finish his work while a...
# ...

# %%
df.isnull().sum() # null values in each column
# Out:
# title               6
# overview          954
# genres              0
# tagline         25045
# vote_average        6
# popularity          5
# dtype: int64

# %%
df = df.dropna(subset = ['title']) # remove null values of 'title' column

# %%
df.isnull().sum()
# Out:
# title               0
# overview          954
# genres              0
# tagline         25039
# vote_average        0
# popularity          0
# dtype: int64

# %%
# 954 rows in 'overview` column have null values
# fill them with empty spaces instead of NaN

df['overview'] = df['overview'].fillna('')

# %%
# work on genres
# 3 genres : Animation, Comedy, Family

df.iloc[0]['genres']
# Out:
# "[{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]"

# %%
import ast

# converting
# [{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]
# to
# Animation Comedy Family

# %%
# Create a lambda expression for conversion of genres

df['genres'] = df['genres'].apply(lambda x : " ".join([i['name'] for i in ast.literal_eval(x)]))

# %%
df.head()
# Out:
#                          title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
# 3  Cheated on, mistreated and stepped on, the wom...
# 4  Just when George Banks has recovered from his ...
#
#                      genres  \
# 0   Animation Comedy Family
# 1  Adventure Fantasy Family
# 2            Romance Comedy
# 3      Comedy Drama Romance
# 4                    Comedy
#
#                                              tagline  vote_average popularity
# 0                                                NaN           7.7  21.946943
# 1          Roll the dice and unleash the excitement!           6.9  17.015539
# ...

# %%
# filling 25k NaN rows of 'tagline' column with empty spaces

df['tagline'] = df['tagline'].fillna('')

# %%
df.isnull().sum()
# Out:
# title           0
# overview        0
# genres          0
# tagline         0
# vote_average    0
# popularity      0
# dtype: int64

# %%
# combine these columns so that we can vectorize them at once instead of doing one by one

df['tags'] = df['overview'] + " " + df['genres'] + " " + df['tagline']

# %%
df.head()
# Out:
#                          title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
# 3  Cheated on, mistreated and stepped on, the wom...
# 4  Just when George Banks has recovered from his ...
#
#                      genres  \
# 0   Animation Comedy Family
# 1  Adventure Fantasy Family
# 2            Romance Comedy
# 3      Comedy Drama Romance
# 4                    Comedy
#
#                                              tagline  vote_average popularity  \
# 0                                                              7.7  21.946943
# 1          Roll the dice and unleash the excitement!           6.9  17.015539
# ...

# %% [markdown]
# # **NLP Text Pre-processing**

# %%
df['tags'][1]
# Out:
# "When siblings Judy and Peter discover an enchanted board game that opens the door to a magical world, they unwittingly invite Alan -- an adult who's been trapped inside the game for 26 years -- into their living room. Alan's only hope for freedom is to finish the game, which proves risky as all three find themselves running from giant rhinoceroses, evil monkeys and other terrifying creatures. Adventure Fantasy Family Roll the dice and unleash the excitement!"

# %%
# Remove punctuations - don't impact the sentence much. [, -- ' etc....]
# Remove stop-words like [when, the, and, an, that, the, to, a]

# Split words and create tokens out of them
# Use Limitization before creating tokens

# Stemming & Lemmatization :
# both are text preprocessing techniques in NLP, used to reduce words to their base or root forms
# Stemming uses crude rule-based suffix stripping
# Lemmatization uses vocabulary and grammar context to return valid dictionary word (lemma)

# Example:
# 'end' & 'ending' -- both are same, but in different forms
# take 'ending' to its root form i.e., 'end'

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re

# %%
# downloading packages
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
# create objects of stopwords & wordnet

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# %%
# Function created to apply on 'tags'
def preprocess_text(text):

  # lower case
  text = str(text).lower()

  # remove punctuations
  text = re.sub(r'[^a-zA-Z\s]', '', text)

  # tokenization
  words = text.split()

  # remove stopwords
  # word which is present in 'words' and not in 'stop_words' - REMAIN
  # word which is present in 'words' and in 'stop_words' - REMOVED
  words = [word for word in words if word not in stop_words]

  # lemmatize
  words = [lemmatizer.lemmatize(word) for word in words]

  return " ".join(words)

# %%
# before preprocessing
df['tags'][1]
# Out:
# "When siblings Judy and Peter discover an enchanted board game that opens the door to a magical world, they unwittingly invite Alan -- an adult who's been trapped inside the game for 26 years -- into their living room. Alan's only hope for freedom is to finish the game, which proves risky as all three find themselves running from giant rhinoceroses, evil monkeys and other terrifying creatures. Adventure Fantasy Family Roll the dice and unleash the excitement!"

# %%
# Apply preprocessing function on 'tags'
df['tags'] = df['tags'].apply(preprocess_text)

# %%
# after preprocessing
df['tags'][1]
# Out:
# 'sibling judy peter discover enchanted board game open door magical world unwittingly invite alan adult who trapped inside game year living room alans hope freedom finish game prof risky three find running giant rhinoceros evil monkey terrifying creature adventure fantasy family roll dice unleash excitement'

# %%
df['tags'][0]
# Out:
# 'led woody andys toy live happily room andys birthday brings buzz lightyear onto scene afraid losing place andys heart woody plot buzz circumstance separate buzz woody owner duo eventually learns put aside difference animation comedy family'

# %% [markdown]
# # **Text Vectorization**

# %%
df.head()
# Out:
#                          title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
# 3  Cheated on, mistreated and stepped on, the wom...
# 4  Just when George Banks has recovered from his ...
#
#                      genres  \
# 0   Animation Comedy Family
# 1  Adventure Fantasy Family
# 2            Romance Comedy
# 3      Comedy Drama Romance
# 4                    Comedy
#
#                                              tagline  vote_average popularity  \
# 0                                                              7.7  21.946943
# 1          Roll the dice and unleash the excitement!           6.9  17.015539
# ...

# %%
# When we removed duplicates, indices of those also gets removed
# We need to reset the indices to bring uniformity

df = df.reset_index(drop = True)

# %%
# Create a series of the indices using pandas

indices = pd.Series(df.index, index = df['title']).drop_duplicates()
indices
# Out:
# title
# Toy Story                          0
# Jumanji                            1
# Grumpier Old Men                   2
# Waiting to Exhale                  3
# Father of the Bride Part II        4
#                                ...
# Subdue                         45442
# Century of Birthing            45443
# Betrayal                       45444
# Satan Triumphant               45445
# Queerama                       45446
# Length: 45447, dtype: int64

# %%
df['tags'][1]
# Out:
# 'sibling judy peter discover enchanted board game open door magical world unwittingly invite alan adult who trapped inside game year living room alans hope freedom finish game prof risky three find running giant rhinoceros evil monkey terrifying creature adventure fantasy family roll dice unleash excitement'

# %%
# Apply vectorization on tags
# Convert the long sentences into numbers using TF-IDF

# One Hot Encoding - Create a vector for every word
# Vector shape was dependent on number of words

# Bag of Words - use Vocabulary
# Forgets word order, misses the context

# TF-IDF
# Used to score how important a word is to a document within large collection of text

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# ngram_range(min, max)
# tells your vectorizer minimum and maximum size of these word sequences to extract

# Example : [ the cat sits ]
# ngram_range(1, 1) : "the", "cat", "sits"
# ngram_range(1, 2) : "the", "cat", "sits", "the cat", "cat sits"

# %%
tfidf = TfidfVectorizer(max_features = 50000, ngram_range = (1,2), stop_words = 'english')

# %%
# 'tags' converted into a 2d matrix
# we have 45447 movies in our dataframe
# for every movie out of 45447 movies, a vector of size 50000 is created
# the matrix shape - [45447][50000] - (rows : 45447, columns : 50000)

tfidf_matrix = tfidf.fit_transform(df['tags'])

# %%
tfidf_matrix # Shape of matrix
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 1548114 stored elements and shape (45447, 50000)>

# %% [markdown]
# # **Cosine Similarity**
# - A metric used to measure how similar two text documents are, regardless of their size.
# - It calculates cosine of the angle between two multi-dimensional vectors projected in a geometric space
# - In text processing, closer the final score is to 1, more similar the context of documents
# - cos(0) = 1 | cos(45) = 0.71 | cos(90) = 0

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
# n is number of movies to recommend based on given movie 'title'

def recommend(title, n = 10):
  if title not in indices:
    return ['Movie not found']

  idx = indices[title]

  # use cosine similarity to compare given movie with all other movies
  similarity_score = cosine_similarity(tfidf_matrix[idx], tfidf_matrix).flatten()

  # argsort() : sort on basis of index
  # use index slicing to extract top 10
  similar_idx = similarity_score.argsort()[::-1][1:n+1]

  return df['title'].iloc[similar_idx]

# %%
recommend('Toy Story')
# Out:
# 2996                Toy Story 2
# 15344               Toy Story 3
# 24512                 Small Fry
# 28972           Superstar Goofy
# 17184                 Group Sex
# 6434     What's Up, Tiger Lily?
# 11396    For Your Consideration
# 1071      Rebel Without a Cause
# 1931                  Condorman
# 485                      Malice
# Name: title, dtype: object

# %%
recommend('Avengers')
# Out:
# ['Movie not found']

# %%
recommend('Small Fry')
# Out:
# 0                                      Toy Story
# 24126                                     Aladin
# 8079           Harold & Kumar Go to White Castle
# 15386                              Mercy Streets
# 8109                                  Triggermen
# 13757                      The Wing or the Thigh
# 40839    An American Girl: Chrissa Stands Strong
# 45253                       Hemo The Magnificent
# 26104                            Switching Goals
# 12861                                  Gigantics
# Name: title, dtype: object

# %%
recommend('Rebel Without a Cause')
# Out:
# 18072                   Tomboy
# 1081             The Sleepover
# 26338    Soccer Dog: The Movie
# 24512                Small Fry
# 0                    Toy Story
# 45007            Inconceivable
# 35621          Science Fiction
# 20298                    Sunny
# 25446                     1981
# 36956        Good Boy, Bad Boy
# Name: title, dtype: object

# %%
recommend('Avatar', 5)
# Out:
# 26547                  Avatar 2
# 13883      The Inhabited Island
# 26553            Thor: Ragnarok
# 43431    Moontrap: Target Earth
# 14119      The Three Musketeers
# Name: title, dtype: object

# %%
recommend('Thor')
# Out:
# 21932                          Thor: The Dark World
# 17491                                 Almighty Thor
# 38830                                     I Am Thor
# 20788                         Thor: Tales of Asgard
# 26553                                Thor: Ragnarok
# 41145                                     Team Thor
# 44234                               Prince of Space
# 35242    Marvel Super Hero Adventures: Frost Fight!
# 19524                                      Kon-Tiki
# 22465                      Dragon Ball Z: Lord Slug
# Name: title, dtype: object

# %% [markdown]
# # Creating Pickle Files

# %%
import pickle

# use tfidf matrix and open a pickle file, saved in read binary format
pickle.dump(tfidf_matrix, open('tfidf_matrix.pkl', 'wb'))

pickle.dump(indices, open('indices.pkl', 'wb'))

df.to_pickle('df.pkl')

pickle.dump(tfidf, open('tfidf.pkl', 'wb'))
